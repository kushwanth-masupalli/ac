# %%
#import required libraries 
import nltk
nltk.download("punkt_tab")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\masup\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\masup\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
file = open("sample.txt","r",encoding="utf-8")
text = file.read()
print(text)
# Out:
# Iron Man is a 2008 American superhero film based on the Marvel Comics character of the same name.
# Produced by Marvel Studios and distributed by Paramount Pictures,[a] it is the first film in the
# Marvel Cinematic Universe (MCU). Directed by Jon Favreau from a screenplay by the writing teams
# of Mark Fergus and Hawk Ostby, and Art Marcum and Matt Holloway, the film stars Robert Downey
# Jr. as Tony Stark / Iron Man alongside Terrence Howard, Jeff Bridges, Gwyneth Paltrow, Leslie
# Bibb, and Shaun Toub. In the film, following his escape from captivity by a terrorist group,
# world-famous industrialist and master engineer Stark builds a mechanized suit of armor and
# becomes the superhero Iron Man.

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Iron Man is a 2008 American superhero film based on the Marvel Comics character of the same name.', 'Produced by Marvel Studios and distributed by Paramount Pictures,[a] it is the first film in the\nMarvel Cinematic Universe (MCU).', 'Directed by Jon Favreau from a screenplay by the writing teams\nof Mark Fergus and Hawk Ostby, and Art Marcum and Matt Holloway, the film stars Robert Downey\nJr. as Tony Stark / Iron Man alongside Terrence Howard, Jeff Bridges, Gwyneth Paltrow, Leslie \nBibb, and Shaun Toub.', 'In the film, following his escape from captivity by a terrorist group,\nworld-famous industrialist and master engineer Stark builds a mechanized suit of armor and\nbecomes the superhero Iron Man.']

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(text) 
print(words)
# Out:
# ['Iron', 'Man', 'is', 'a', '2008', 'American', 'superhero', 'film', 'based', 'on', 'the', 'Marvel', 'Comics', 'character', 'of', 'the', 'same', 'name', '.', 'Produced', 'by', 'Marvel', 'Studios', 'and', 'distributed', 'by', 'Paramount', 'Pictures', ',', '[', 'a', ']', 'it', 'is', 'the', 'first', 'film', 'in', 'the', 'Marvel', 'Cinematic', 'Universe', '(', 'MCU', ')', '.', 'Directed', 'by', 'Jon', 'Favreau', 'from', 'a', 'screenplay', 'by', 'the', 'writing', 'teams', 'of', 'Mark', 'Fergus', 'and', 'Hawk', 'Ostby', ',', 'and', 'Art', 'Marcum', 'and', 'Matt', 'Holloway', ',', 'the', 'film', 'stars', 'Robert', 'Downey', 'Jr.', 'as', 'Tony', 'Stark', '/', 'Iron', 'Man', 'alongside', 'Terrence', 'Howard', ',', 'Jeff', 'Bridges', ',', 'Gwyneth', 'Paltrow', ',', 'Leslie', 'Bibb', ',', 'and', 'Shaun', 'Toub', '.', 'In', 'the', 'film', ',', 'following', 'his', 'escape', 'from', 'captivity', 'by', 'a', 'terrorist', 'group', ',', 'world-famous', 'industrialist', 'and', 'master', 'engineer', 'Stark', 'builds', 'a', 'mechanized', 'suit', 'of', 'armor', 'and', 'becomes', 'the', 'superhero', 'Iron', 'Man', '.']

# %%
from nltk.corpus import stopwords 

stop_words = set(stopwords.words("english"))

filtered_words = []

for word in words :
    if word.lower() not in stop_words:
        filtered_words.append(word)

print(filtered_words)
# Out:
# ['Iron', 'Man', '2008', 'American', 'superhero', 'film', 'based', 'Marvel', 'Comics', 'character', 'name', '.', 'Produced', 'Marvel', 'Studios', 'distributed', 'Paramount', 'Pictures', ',', '[', ']', 'first', 'film', 'Marvel', 'Cinematic', 'Universe', '(', 'MCU', ')', '.', 'Directed', 'Jon', 'Favreau', 'screenplay', 'writing', 'teams', 'Mark', 'Fergus', 'Hawk', 'Ostby', ',', 'Art', 'Marcum', 'Matt', 'Holloway', ',', 'film', 'stars', 'Robert', 'Downey', 'Jr.', 'Tony', 'Stark', '/', 'Iron', 'Man', 'alongside', 'Terrence', 'Howard', ',', 'Jeff', 'Bridges', ',', 'Gwyneth', 'Paltrow', ',', 'Leslie', 'Bibb', ',', 'Shaun', 'Toub', '.', 'film', ',', 'following', 'escape', 'captivity', 'terrorist', 'group', ',', 'world-famous', 'industrialist', 'master', 'engineer', 'Stark', 'builds', 'mechanized', 'suit', 'armor', 'becomes', 'superhero', 'Iron', 'Man', '.']

# %%
from nltk.probability import FreqDist 

freq = FreqDist(filtered_words)

for word,count in freq.items():
    print(word ,":",count)
# Out:
# Iron : 3
# Man : 3
# 2008 : 1
# American : 1
# superhero : 2
# film : 4
# based : 1
# Marvel : 3
# Comics : 1
# character : 1
# name : 1
# . : 4
# Produced : 1
# Studios : 1
# distributed : 1
# Paramount : 1
# Pictures : 1
# , : 9
# [ : 1
# ] : 1
# first : 1
# Cinematic : 1
# Universe : 1
# ( : 1
# MCU : 1
# ) : 1
# Directed : 1
# Jon : 1
# Favreau : 1
# screenplay : 1
# writing : 1
# teams : 1
# Mark : 1
# Fergus : 1
# Hawk : 1
# Ostby : 1
# Art : 1
# Marcum : 1
# Matt : 1
# Holloway : 1
# stars : 1
# Robert : 1
# Downey : 1
# Jr. : 1
# Tony : 1
# Stark : 2
# / : 1
# alongside : 1
# Terrence : 1
# Howard : 1
# Jeff : 1
# Bridges : 1
# Gwyneth : 1
# Paltrow : 1
# Leslie : 1
# Bibb : 1
# Shaun : 1
# Toub : 1
# following : 1
# escape : 1
# captivity : 1
# terrorist : 1
# group : 1
# world-famous : 1
# industrialist : 1
# master : 1
# engineer : 1
# builds : 1
# mechanized : 1
# suit : 1
# armor : 1
# becomes : 1

# %%
th =5
frequent_words = [] 

for word, count in freq.items():
    if count >=2:
        frequent_words.append(word)

print(frequent_words)
# Out:
# ['Iron', 'Man', 'superhero', 'film', 'Marvel', '.', ',', 'Stark']
