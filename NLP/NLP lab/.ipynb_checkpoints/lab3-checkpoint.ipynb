# %%
# write a program to implement stemming of a word 
import nltk
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

word = "organization"

baseword = stemmer.stem(word)
print(f"the stemmed word is {baseword}")
# Out:
# the stemmed word is organ

# %%
from nltk.stem import RegexpStemmer

custom_rule = r'ing$'
regexp_stemmer = RegexpStemmer(custom_rule)

word = 'running'
stemmed_word = regexp_stemmer.stem(word)

print(f'Original Word: {word}')
print(f'Stemmed Word: {stemmed_word}')
# Out:
# Original Word: running
# Stemmed Word: runn

# %%
from nltk.stem import LancasterStemmer

stemmer = LancasterStemmer()

word  = "organization"

stemmed_word = stemmer.stem(word)

print("Original words:", word)
print("Stemmed words:", stemmed_word)
# Out:
# Original words: organization
# Stemmed words: org

# %%
# write a python program to implement lemmatization 
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet 

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')

def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    print(nltk.pos_tag([word]))
    tag_dict ={ "J":wordnet.ADJ, "N":wordnet.NOUN , "V":wordnet.VERB, "R":wordnet.ADV}

    return tag_dict.get(tag,wordnet.NOUN)

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("better",get_wordnet_pos("better")))
# Out:
# [('better', 'RBR')]
# well
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\masup\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\masup\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
